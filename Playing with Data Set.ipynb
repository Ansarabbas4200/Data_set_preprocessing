# %% [markdown]
# ## Minimum and Maximum Salary

# %%
import pandas as pd

# %%
data = pd.read_csv("D:\ProgrammerForceClass\Pandas\ds_salaries.csv")
data
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
data_analyst = data[data.job_title == "Data Analyst"]
data_analyst
# Out:
#      Unnamed: 0  work_year experience_level employment_type     job_title  \
# 5             5       2020               EN              FT  Data Analyst
# 14           14       2020               MI              FT  Data Analyst
# 15           15       2020               MI              FT  Data Analyst
# 34           34       2020               MI              FT  Data Analyst
# 38           38       2020               EN              FT  Data Analyst
# ..          ...        ...              ...             ...           ...
# 597         597       2022               SE              FT  Data Analyst
# 600         600       2022               EN              FT  Data Analyst
# 601         601       2022               EN              FT  Data Analyst
# 604         604       2022               SE              FT  Data Analyst
# 605         605       2022               SE              FT  Data Analyst
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
data_analyst = data_analyst[['salary_in_usd', 'company_size']]
data_analyst
# Out:
#      salary_in_usd company_size
# 5            72000            L
# 14           85000            L
# 15            8000            L
# 34           46759            L
# 38           10000            S
# ..             ...          ...
# 597         170000            M
# 600          67000            M
# 601          52000            M
# 604         129000            M
# 605         150000            M
#
# [97 rows x 2 columns]

# %%
data_analyst_max = data_analyst[data_analyst.salary_in_usd == data_analyst.salary_in_usd.max()]
data_analyst_max
# Out:
#      salary_in_usd company_size
# 233         200000            L

# %%
data_analyst_min = data_analyst[data_analyst.salary_in_usd == data_analyst.salary_in_usd.min()]
data_analyst_min
# Out:
#     salary_in_usd company_size
# 50           6072            S

# %% [markdown]
# #### Maximum and minimun salaries with their company size

# %%
final_data = pd.concat([data_analyst_max, data_analyst_min])
final_data
# Out:
#      salary_in_usd company_size
# 233         200000            L
# 50            6072            S

# %%
final_data.to_csv("D:\ProgrammerForceClass\Pandas\max_min_salary.csv")

# %% [markdown]
# ## Region as per have more jobs data engineer

# %%
data_engineers = data[data.job_title.str.contains('data engineer', case=False)]
data_engineers
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 2             2       2020               SE              FT
# 9             9       2020               SE              FT
# 16           16       2020               EN              FT
# 17           17       2020               SE              FT
# 19           19       2020               MI              FT
# ..          ...        ...              ...             ...
# 579         579       2022               SE              FT
# 582         582       2022               SE              FT
# 583         583       2022               SE              FT
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
#
#               job_title   salary salary_currency  salary_in_usd  \
# 2     Big Data Engineer    85000             GBP         109024
# 9    Lead Data Engineer   125000             USD         125000
# ...

# %%
jobs_by_location = data_engineers.groupby('company_location')['job_title'].count().reset_index()
jobs_by_location
# Out:
#    company_location  job_title
# 0                AT          1
# 1                CA          1
# 2                CH          1
# 3                DE          5
# 4                ES          5
# 5                FR          2
# 6                GB         24
# 7                GR          5
# 8                IN          4
# 9                IR          1
# 10               JP          1
# 11               MD          1
# 12               MT          1
# 13               MX          1
# 14               NL          2
# 15               NZ          1
# 16               PL          1
# 17               RO          1
# 18               SG          1
# 19               TR          2
# 20               US         97

# %%
sorted_jobs_by_location = jobs_by_location.sort_values('job_title', ascending = False)
sorted_jobs_by_location.to_csv("D:\ProgrammerForceClass\Pandas\most_jobs_region.csv")
sorted_jobs_by_location
# Out:
#    company_location  job_title
# 20               US         97
# 6                GB         24
# 3                DE          5
# 4                ES          5
# 7                GR          5
# 8                IN          4
# 14               NL          2
# 19               TR          2
# 5                FR          2
# 18               SG          1
# 17               RO          1
# 16               PL          1
# 15               NZ          1
# 0                AT          1
# 13               MX          1
# 12               MT          1
# 11               MD          1
# 1                CA          1
# 9                IR          1
# 2                CH          1
# 10               JP          1
